# %% [markdown]
# # End to End Workflow Demo

# %%
steps = [
    "Upload resume",
    "Extract content",
    "Paste job description",
    "Generate ATS report",
    "Generate resume bullets",
    "Generate interview questions",
    "Use AI chat"
]

for step in steps:
    print(step)

# %% [markdown]
# # Model Comparison

# %%
models = [
    "llama3:latest",
    "mistral:latest",
    "phi3:latest",
    "deepseek-coder:latest"
]

for model in models:
    print(f"Evaluate performance for: {model}")
